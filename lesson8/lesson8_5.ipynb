# %%
import numpy as np
import pandas as pd

scores =  np.random.randint(50,101,size=(50,5))
df = pd.DataFrame(scores,
                  columns = ['國文','英文','數學','歷史','地理'],
                  index = range(1,51)
                  )
df.index.name = '學號'
df.columns.name = '科目'
df
# Out:
# 科目   國文  英文   數學  歷史  地理
# 學號
# 1    70  59   60  60  60
# 2    59  64   58  84  83
# 3    74  63   95  88  66
# 4    72  51   96  72  90
# 5    80  89   70  72  87
# 6    70  61   83  95  61
# 7    92  57   79  70  87
# 8    89  65   84  58  76
# 9   100  98   70  71  91
# 10   96  66   86  86  94
# 11   60  64   74  51  86
# 12   52  56   56  73  96
# 13   74  86   79  60  63
# 14   54  98   63  97  68
# 15   91  51   94  61  91
# 16   68  94   54  81  88
# 17   52  97   60  86  53
# 18   85  74   98  60  86
# 19   58  70  100  83  51
# 20   78  91   62  91  77
# 21   71  91   67  99  58
# 22   50  63   51  72  66
# 23   89  56   67  76  69
# 24   71  63   96  79  54
# 25   55  53   70  64  79
# 26   66  61   76  62  68
# 27   57  82   95  59  73
# 28   95  63   86  66  71
# 29   71  70   62  69  57
# 30   86  70   67  72  54
# 31   92  63   59  70  88
# 32   55  89   51  74  57
# 33   99  75   99  87  97
# 34   63  96   53  61  62
# 35   96  61   98  88  55
# ...

# %%
sum_value = df.sum(axis=1)
mean_value = df.mean(axis=1)

# %%
df['總分'] = sum_value
df['平均'] = mean_value

# %%
df1 = df.sort_values(by='總分',ascending=False)
df1
# Out:
# 科目   國文  英文   數學  歷史  地理   總分    平均
# 學號
# 33   99  75   99  87  97  457  91.4
# 9   100  98   70  71  91  430  86.0
# 10   96  66   86  86  94  428  85.6
# 48   76  87   78  86  90  417  83.4
# 18   85  74   98  60  86  403  80.6
# 20   78  91   62  91  77  399  79.8
# 35   96  61   98  88  55  398  79.6
# 5    80  89   70  72  87  398  79.6
# 43   94  88   60  72  79  393  78.6
# 15   91  51   94  61  91  388  77.6
# 37  100  53   72  85  77  387  77.4
# 21   71  91   67  99  58  386  77.2
# 3    74  63   95  88  66  386  77.2
# 7    92  57   79  70  87  385  77.0
# 16   68  94   54  81  88  385  77.0
# 28   95  63   86  66  71  381  76.2
# 4    72  51   96  72  90  381  76.2
# 46   70  65   87  87  72  381  76.2
# 14   54  98   63  97  68  380  76.0
# 50   77  73   71  53  99  373  74.6
# 31   92  63   59  70  88  372  74.4
# 8    89  65   84  58  76  372  74.4
# 6    70  61   83  95  61  370  74.0
# 40   56  72   84  97  59  368  73.6
# 27   57  82   95  59  73  366  73.2
# ...

# %%
rank_value = df1['總分'].rank(ascending=False,method='min')
df1['排名'] = rank_value
df1
# Out:
# 科目   國文  英文   數學  歷史  地理   總分    平均    排名
# 學號
# 33   99  75   99  87  97  457  91.4   1.0
# 9   100  98   70  71  91  430  86.0   2.0
# 10   96  66   86  86  94  428  85.6   3.0
# 48   76  87   78  86  90  417  83.4   4.0
# 18   85  74   98  60  86  403  80.6   5.0
# 20   78  91   62  91  77  399  79.8   6.0
# 35   96  61   98  88  55  398  79.6   7.0
# 5    80  89   70  72  87  398  79.6   7.0
# 43   94  88   60  72  79  393  78.6   9.0
# 15   91  51   94  61  91  388  77.6  10.0
# 37  100  53   72  85  77  387  77.4  11.0
# 21   71  91   67  99  58  386  77.2  12.0
# 3    74  63   95  88  66  386  77.2  12.0
# 7    92  57   79  70  87  385  77.0  14.0
# 16   68  94   54  81  88  385  77.0  14.0
# 28   95  63   86  66  71  381  76.2  16.0
# 4    72  51   96  72  90  381  76.2  16.0
# 46   70  65   87  87  72  381  76.2  16.0
# 14   54  98   63  97  68  380  76.0  19.0
# 50   77  73   71  53  99  373  74.6  20.0
# 31   92  63   59  70  88  372  74.4  21.0
# ...

# %%
def max_scores(row) ->int:
    return row.min()

df1[['國文','英文','數學','歷史','地理']].apply(max_scores,axis=1)
# Out:
# 學號
# 33    75
# 9     70
# 10    66
# 48    76
# 18    60
# 20    62
# 35    55
# 5     70
# 43    60
# 15    51
# 37    53
# 21    58
# 3     63
# 7     57
# 16    54
# 28    63
# 4     51
# 46    65
# 14    54
# 50    53
# 31    59
# 8     58
# 6     61
# 40    56
# 27    57
# 24    54
# 19    51
# 13    60
# 38    53
# 23    56
# 47    56
# 30    54
# 45    50
# 2     58
# 17    52
# 44    50
# 41    54
# 36    59
# 42    53
# 34    53
# 11    51
# 12    52
# 26    61
# 29    57
# 32    51
# 25    53
# 49    54
# 39    55
# 1     59
# 22    50
# dtype: int64

# %%
def max_scores(row) :
    return pd.Series([row.min(),row.max(),row.std()],index = ['最低分','最高分','標準差'])

df1[['國文','英文','數學','歷史','地理']].apply(max_scores,axis=1)
# Out:
#      最低分    最高分        標準差
# 學號
# 33  75.0   99.0  10.430724
# 9   70.0  100.0  14.543040
# 10  66.0   96.0  11.865918
# 48  76.0   90.0   6.066300
# 18  60.0   98.0  14.310835
# 20  62.0   91.0  12.029131
# 35  55.0   98.0  20.181675
# 5   70.0   89.0   8.561542
# 43  60.0   94.0  13.371612
# 15  51.0   94.0  20.069878
# 37  53.0  100.0  17.271364
# 21  58.0   99.0  17.152259
# 3   63.0   95.0  13.881643
# 7   57.0   92.0  13.946326
# 16  54.0   94.0  16.093477
# 28  63.0   95.0  13.736812
# 4   51.0   96.0  17.697457
# 46  65.0   87.0  10.183320
# 14  54.0   98.0  20.260800
# 50  53.0   99.0  16.456002
# 31  59.0   92.0  14.842507
# 8   58.0   89.0  12.895736
# 6   61.0   95.0  14.798649
# 40  56.0   97.0  17.184295
# 27  57.0   95.0  15.943651
# 24  54.0   96.0  16.040574
# 19  51.0  100.0  19.654516
# 13  60.0   86.0  10.876580
# 38  53.0   91.0  13.820275
# 23  56.0   89.0  12.177849
# 47  56.0   77.0   8.689074
# 30  54.0   86.0  11.454257
# 45  50.0   90.0  16.468151
# ...

# %%
def max_scores(row) :
    less_60_count = len(row[row < 60])
    return pd.Series([row.min(),row.max(),row.std(),less_60_count],index = ['最低分','最高分','標準差','不及格數量'])

df2 = df1[['國文','英文','數學','歷史','地理']].apply(max_scores,axis=1)

pd.concat([df1,df2],axis=1)
# Out:
#      國文  英文   數學  歷史  地理   總分    平均    排名   最低分    最高分        標準差  不及格數量
# 學號
# 33   99  75   99  87  97  457  91.4   1.0  75.0   99.0  10.430724    0.0
# 9   100  98   70  71  91  430  86.0   2.0  70.0  100.0  14.543040    0.0
# 10   96  66   86  86  94  428  85.6   3.0  66.0   96.0  11.865918    0.0
# 48   76  87   78  86  90  417  83.4   4.0  76.0   90.0   6.066300    0.0
# 18   85  74   98  60  86  403  80.6   5.0  60.0   98.0  14.310835    0.0
# 20   78  91   62  91  77  399  79.8   6.0  62.0   91.0  12.029131    0.0
# 35   96  61   98  88  55  398  79.6   7.0  55.0   98.0  20.181675    1.0
# 5    80  89   70  72  87  398  79.6   7.0  70.0   89.0   8.561542    0.0
# 43   94  88   60  72  79  393  78.6   9.0  60.0   94.0  13.371612    0.0
# 15   91  51   94  61  91  388  77.6  10.0  51.0   94.0  20.069878    1.0
# 37  100  53   72  85  77  387  77.4  11.0  53.0  100.0  17.271364    1.0
# 21   71  91   67  99  58  386  77.2  12.0  58.0   99.0  17.152259    1.0
# ...
