# %%
import wget
wget.download('https://github.com/roberthsu2003/__2025_01_04_chihlee__/raw/refs/heads/main/ChineseFont.ttf')
# Out:
# 'ChineseFont (1).ttf'

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
import matplotlib as mlp
fontManager.addfont('ChineseFont.ttf')
mlp.rc('font',family='ChineseFont')

# %%
#建立"圖面" 及 "圖表區塊"
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)

# 設定 x 軸和 y 軸的刻度值
axes.set_xticks([1, 2, 3, 4, 5])
axes.set_yticks([10, 20, 30, 40, 50])

plt.show()

# %%
#建立"圖面" 及 "圖表區塊"
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)

# # 設定 x 軸和 y 軸的刻度值
# axes.set_xticks([1, 2, 3, 4, 5])
# axes.set_yticks([10, 20, 30, 40, 50])

#在圖表內畫線並標註
axes.plot([12,43,29,74,36,22,9],marker = 'o', color=('red'), linestyle=('-.'))

plt.show()

# %%
#建立"圖面" 及 "圖表區塊"
figure = plt.figure(figsize=(10,6))
axes1 = figure.add_subplot(2,1,1)
axes2 = figure.add_subplot(2,1,2)

#在圖表內畫線並標註
axes_up = axes1.plot([12,43,29,74,36,22,9],marker = 'o', color=('red'), linestyle=('-.'))
axes_down = axes2.plot([63,27,69,41,3,18,51],marker = 'x', color=('blue'), linestyle=(':'))

plt.show()
