# %%
P1={'name':'王軼群',
'age':'46',
'city':'Taipei'}
P1
# Out:
# {'name': '王軼群', 'age': '46', 'city': 'Taipei'}

# %%
print(P1['name'])
print(P1.get('age'))
# Out:
# 王軼群
# 46

# %%
del P1['city']
P1.pop('age')
# Out:
# '46'

# %%
p1.pop('age')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p1.pop('age')
#
# NameError: name 'p1' is not defined

# %% [markdown]
# - 如何依順序取出'串列資料'和'映射資料'的元素值
# - for_in迴圈

# %%
fruits = ['蘋果', '橘子', '香蕉']
for fruit in fruits:
    print(fruit)
# Out:
# 蘋果
# 橘子
# 香蕉

# %%
for index,fruit in enumerate(fruits):
    print(index,fruit,sep='->')
    print("=================");
# Out:
# 0->蘋果
# =================
# 1->橘子
# =================
# 2->香蕉
# =================

# %%
cities = {
    'Taipei':'台北市',
    'New Taipei':'新北市',
    'Taoyuan':'桃園',
    'Taichung':'台中',
    'Tainan':'台南',
    'Kaohsiung':'高雄',
    'Keelung':'基隆',
    'Hsinchu':'新竹',
    'Chiayi':'嘉義',
    'Hualien':'花蓮'}
for key, value in cities.items():
    print(f"{key}:{value}")
# Out:
# Taipei:台北市
# New Taipei:新北市
# Taoyuan:桃園
# Taichung:台中
# Tainan:台南
# Kaohsiung:高雄
# Keelung:基隆
# Hsinchu:新竹
# Chiayi:嘉義
# Hualien:花蓮

# %%
import random

#一個學生(student)的dictionary,格式如下:
#{'name':'value','chinese':78,'english':98,'math':67,'history':87,'health':76}
#請使用list幫我建立50個學生
students = []
students.append({'name': 'Student1', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student2', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student3', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student4', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student5', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student6', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student7', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student8', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student9', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student10', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student11', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student12', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student13', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student14', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student15', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student16', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student17', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student18', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student19', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student20', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student21', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student22', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student23', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student24', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student25', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student26', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student27', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student28', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student29', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student30', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student31', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student32', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student33', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student34', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student35', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student36', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student37', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student38', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student39', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student40', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student41', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student42', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student43', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student44', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student45', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student46', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student47', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student48', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student49', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student50', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students
# Out:
# [{'name': 'Student1',
#   'chinese': 79,
#   'english': 75,
#   'math': 66,
#   'history': 62,
#   'health': 71},
#  {'name': 'Student2',
#   'chinese': 95,
#   'english': 100,
#   'math': 95,
#   'history': 87,
#   'health': 93},
#  {'name': 'Student3',
#   'chinese': 64,
#   'english': 100,
#   'math': 95,
#   'history': 98,
#   'health': 80},
#  {'name': 'Student4',
#   'chinese': 84,
#   'english': 76,
#   'math': 82,
#   'history': 97,
#   'health': 79},
#  {'name': 'Student5',
#   'chinese': 60,
#   'english': 72,
#   'math': 93,
#   'history': 93,
#   'health': 99},
#  {'name': 'Student6',
#   'chinese': 66,
#   'english': 76,
#   'math': 73,
#   'history': 95,
#   'health': 88},
#  {'name': 'Student7',
#   'chinese': 68,
#   'english': 72,
#   'math': 67,
#   'history': 80,
#   'health': 85},
#  {'name': 'Student8',
#   'chinese': 68,
#   'english': 100,
#   'math': 79,
#   'history': 80,
#   'health': 77},
#  {'name': 'Student9',
#   'chinese': 75,
#   'english': 70,
#   'math': 80,
#   'history': 82,
#   'health': 77},
#  {'name': 'Student10',
#   'chinese': 93,
#   'english': 75,
#   'math': 100,
#   'history': 90,
#   'health': 63},
#  {'name': 'Student11',
#   'chinese': 67,
#   'english': 70,
#   'math': 69,
#   'history': 68,
#   'health': 99},
#  {'name': 'Student12',
#   'chinese': 89,
#   'english': 82,
#   'math': 93,
#   'history': 84,
#   'health': 100},
#  {'name': 'Student13',
#   'chinese': 92,
#   'english': 81,
#   'math': 76,
#   'history': 89,
#   'health': 91},
#  {'name': 'Student14',
#   'chinese': 78,
#   'english': 92,
#   'math': 93,
#   'history': 80,
#   'health': 63},
#  {'name': 'Student15',
#   'chinese': 89,
#   'english': 77,
#   'math': 84,
#   'history': 87,
#   'health': 83},
#  {'name': 'Student16',
#   'chinese': 79,
#   'english': 75,
#   'math': 77,
#   'history': 91,
#   'health': 71},
#  {'name': 'Student17',
#   'chinese': 66,
#   'english': 88,
#   'math': 82,
#   'history': 63,
#   'health': 93},
#  {'name': 'Student18',
#   'chinese': 92,
#   'english': 72,
#   'math': 73,
#   'history': 69,
#   'health': 64},
#  {'name': 'Student19',
#   'chinese': 81,
#   'english': 69,
#   'math': 62,
#   'history': 76,
#   'health': 79},
#  {'name': 'Student20',
#   'chinese': 86,
#   'english': 90,
#   'math': 89,
#   'history': 78,
#   'health': 84},
#  {'name': 'Student21',
#   'chinese': 96,
#   'english': 86,
#   'math': 65,
#   'history': 88,
#   'health': 98},
#  {'name': 'Student22',
#   'chinese': 75,
#   'english': 91,
#   'math': 63,
#   'history': 93,
#   'health': 76},
#  {'name': 'Student23',
#   'chinese': 85,
#   'english': 85,
#   'math': 64,
#   'history': 61,
#   'health': 60},
#  {'name': 'Student24',
#   'chinese': 100,
#   'english': 72,
#   'math': 83,
#   'history': 77,
#   'health': 81},
#  {'name': 'Student25',
#   'chinese': 100,
#   'english': 80,
#   'math': 61,
#   'history': 89,
#   'health': 67},
#  {'name': 'Student26',
#   'chinese': 65,
#   'english': 72,
#   'math': 70,
#   'history': 86,
#   'health': 100},
#  {'name': 'Student27',
#   'chinese': 84,
#   'english': 72,
#   'math': 97,
#   'history': 81,
#   'health': 93},
#  {'name': 'Student28',
#   'chinese': 90,
#   'english': 98,
#   'math': 96,
#   'history': 94,
#   'health': 87},
#  {'name': 'Student29',
#   'chinese': 73,
#   'english': 77,
#   'math': 79,
#   'history': 84,
#   'health': 89},
#  {'name': 'Student30',
#   'chinese': 74,
#   'english': 80,
#   'math': 91,
#   'history': 76,
#   'health': 91},
#  {'name': 'Student31',
#   'chinese': 63,
#   'english': 76,
#   'math': 93,
#   'history': 68,
#   'health': 80},
#  {'name': 'Student32',
#   'chinese': 78,
#   'english': 97,
#   'math': 60,
#   'history': 70,
#   'health': 92},
#  {'name': 'Student33',
#   'chinese': 69,
#   'english': 75,
#   'math': 82,
#   'history': 99,
#   'health': 76},
#  {'name': 'Student34',
#   'chinese': 64,
#   'english': 64,
#   'math': 100,
#   'history': 74,
#   'health': 70},
#  {'name': 'Student35',
#   'chinese': 66,
#   'english': 91,
#   'math': 76,
#   'history': 73,
#   'health': 88},
#  {'name': 'Student36',
#   'chinese': 90,
#   'english': 69,
#   'math': 87,
#   'history': 96,
#   'health': 96},
#  {'name': 'Student37',
#   'chinese': 83,
#   'english': 97,
#   'math': 69,
#   'history': 98,
#   'health': 85},
#  {'name': 'Student38',
#   'chinese': 66,
#   'english': 67,
#   'math': 80,
#   'history': 71,
#   'health': 95},
#  {'name': 'Student39',
#   'chinese': 84,
#   'english': 75,
#   'math': 100,
#   'history': 80,
#   'health': 82},
#  {'name': 'Student40',
#   'chinese': 74,
#   'english': 69,
#   'math': 82,
#   'history': 70,
#   'health': 64},
#  {'name': 'Student41',
#   'chinese': 65,
#   'english': 75,
#   'math': 99,
#   'history': 86,
#   'health': 76},
#  {'name': 'Student42',
#   'chinese': 77,
#   'english': 63,
#   'math': 89,
#   'history': 89,
#   'health': 71},
#  {'name': 'Student43',
#   'chinese': 90,
#   'english': 76,
#   'math': 90,
#   'history': 96,
#   'health': 72},
#  {'name': 'Student44',
#   'chinese': 79,
#   'english': 78,
#   'math': 77,
#   'history': 77,
#   'health': 71},
#  {'name': 'Student45',
#   'chinese': 74,
#   'english': 86,
#   'math': 65,
#   'history': 77,
#   'health': 93},
#  {'name': 'Student46',
#   'chinese': 80,
#   'english': 83,
#   'math': 98,
#   'history': 87,
#   'health': 76},
#  {'name': 'Student47',
#   'chinese': 94,
#   'english': 75,
#   'math': 74,
#   'history': 79,
#   'health': 82},
#  {'name': 'Student48',
#   'chinese': 62,
#   'english': 78,
#   'math': 68,
#   'history': 79,
#   'health': 85},
#  {'name': 'Student49',
#   'chinese': 66,
#   'english': 90,
#   'math': 68,
#   'history': 75,
#   'health': 71},
#  {'name': 'Student50',
#   'chinese': 71,
#   'english': 95,
#   'math': 80,
#   'history': 79,
#   'health': 93}]

# %%
import random
students = []
for i in range(1,51):
    students.append(
        {
            'name':f'students{i}',
         'chinese':random.randint(50,100),
         'english':random.randint(50,100),
         'math':random.randint(50,100),
         'history':random.randint(50,100),
         'health':random.randint(50,100)
         }
         )

students_str = str(students)
students_str
# Out:
# "[{'name': 'students1', 'chinese': 65, 'english': 69, 'math': 63, 'history': 82, 'health': 92}, {'name': 'students2', 'chinese': 100, 'english': 75, 'math': 78, 'history': 91, 'health': 94}, {'name': 'students3', 'chinese': 73, 'english': 62, 'math': 71, 'history': 92, 'health': 74}, {'name': 'students4', 'chinese': 55, 'english': 62, 'math': 80, 'history': 90, 'health': 58}, {'name': 'students5', 'chinese': 76, 'english': 59, 'math': 95, 'history': 97, 'health': 78}, {'name': 'students6', 'chinese': 74, 'english': 79, 'math': 67, 'history': 75, 'health': 92}, {'name': 'students7', 'chinese': 85, 'english': 91, 'math': 57, 'history': 89, 'health': 57}, {'name': 'students8', 'chinese': 92, 'english': 69, 'math': 92, 'history': 82, 'health': 99}, {'name': 'students9', 'chinese': 88, 'english': 70, 'math': 83, 'history': 89, 'health': 67}, {'name': 'students10', 'chinese': 82, 'english': 70, 'math': 82, 'history': 63, 'health': 71}, {'name': 'students11', 'chinese': 63, 'english': 57, 'math': 91, 'history': 53, 'health': 96}, {'name': 'students12', 'chinese': 72, 'english': 93, 'math': 75, 'history': 63, 'health': 99}, {'name': 'students13', 'chinese': 76, 'english': 51, 'math': 76, 'history': 55, 'health': 51}, {'name': 'students14', 'chinese': 81, 'english': 77, 'math': 61, 'history': 75, 'health': 71}, {'name': 'students15', 'chinese': 79, 'english': 88, 'math': 58, 'history': 69, 'health': 56}, {'name': 'students16', 'chinese': 72, 'english': 79, 'math': 59, 'history': 95, 'health': 92}, {'name': 'students17', 'chinese': 100, 'english': 72, 'math': 70, 'history': 96, 'health': 52}, {'name': 'students18', 'chinese': 98, 'english': 58, 'math': 95, 'history': 61, 'health': 92}, {'name': 'students19', 'chinese': 70, 'english': 83, 'math': 98, 'history': 78, 'health': 57}, {'name': 'students20', 'chinese': 97, 'english': 97, 'math': 90, 'history': 100, 'health': 79}, {'name': 'students21', 'chinese': 56, 'english': 67, 'math': 80, 'history': 79, 'health': 59}, {'name': 'students22', 'chinese': 82, 'english': 87, 'math': 86, 'history': 93, 'health': 71}, {'name': 'students23', 'chinese': 60, 'english': 70, 'math': 69, 'history': 93, 'health': 65}, {'name': 'students24', 'chinese': 64, 'english': 66, 'math': 75, 'history': 95, 'health': 94}, {'name': 'students25', 'chinese': 93, 'english': 93, 'math': 100, 'history': 88, 'health': 75}, {'name': 'students26', 'chinese': 55, 'english': 51, 'math': 76, 'history': 79, 'health': 73}, {'name': 'students27', 'chinese': 85, 'english': 64, 'math': 51, 'history': 100, 'health': 91}, {'name': 'students28', 'chinese': 68, 'english': 96, 'math': 53, 'history': 75, 'health': 88}, {'name': 'students29', 'chinese': 91, 'english': 63, 'math': 55, 'history': 51, 'health': 57}, {'name': 'students30', 'chinese': 99, 'english': 58, 'math': 84, 'history': 97, 'health': 57}, {'name': 'students31', 'chinese': 99, 'english': 98, 'math': 82, 'history': 86, 'health': 87}, {'name': 'students32', 'chinese': 73, 'english': 76, 'math': 65, 'history': 91, 'health': 95}, {'name': 'students33', 'chinese': 99, 'english': 66, 'math': 59, 'history': 92, 'health': 80}, {'name': 'students34', 'chinese': 98, 'english': 62, 'math': 50, 'history': 62, 'health': 82}, {'name': 'students35', 'chinese': 65, 'english': 77, 'math': 94, 'history': 98, 'health': 74}, {'name': 'students36', 'chinese': 65, 'english': 50, 'math': 70, 'history': 73, 'health': 50}, {'name': 'students37', 'chinese': 65, 'english': 85, 'math': 72, 'history': 90, 'health': 91}, {'name': 'students38', 'chinese': 51, 'english': 60, 'math': 100, 'history': 58, 'health': 90}, {'name': 'students39', 'chinese': 89, 'english': 54, 'math': 88, 'history': 54, 'health': 87}, {'name': 'students40', 'chinese': 67, 'english': 64, 'math': 67, 'history': 98, 'health': 61}, {'name': 'students41', 'chinese': 97, 'english': 91, 'math': 79, 'history': 100, 'health': 80}, {'name': 'students42', 'chinese': 76, 'english': 53, 'math': 67, 'history': 75, 'health': 100}, {'name':  ...

# %%
for scores in students:
    print(scores)
# Out:
# {'name': 'students1', 'chinese': 65, 'english': 69, 'math': 63, 'history': 82, 'health': 92}
# {'name': 'students2', 'chinese': 100, 'english': 75, 'math': 78, 'history': 91, 'health': 94}
# {'name': 'students3', 'chinese': 73, 'english': 62, 'math': 71, 'history': 92, 'health': 74}
# {'name': 'students4', 'chinese': 55, 'english': 62, 'math': 80, 'history': 90, 'health': 58}
# {'name': 'students5', 'chinese': 76, 'english': 59, 'math': 95, 'history': 97, 'health': 78}
# {'name': 'students6', 'chinese': 74, 'english': 79, 'math': 67, 'history': 75, 'health': 92}
# {'name': 'students7', 'chinese': 85, 'english': 91, 'math': 57, 'history': 89, 'health': 57}
# {'name': 'students8', 'chinese': 92, 'english': 69, 'math': 92, 'history': 82, 'health': 99}
# {'name': 'students9', 'chinese': 88, 'english': 70, 'math': 83, 'history': 89, 'health': 67}
# {'name': 'students10', 'chinese': 82, 'english': 70, 'math': 82, 'history': 63, 'health': 71}
# {'name': 'students11', 'chinese': 63, 'english': 57, 'math': 91, 'history': 53, 'health': 96}
# {'name': 'students12', 'chinese': 72, 'english': 93, 'math': 75, 'history': 63, 'health': 99}
# {'name': 'students13', 'chinese': 76, 'english': 51, 'math': 76, 'history': 55, 'health': 51}
# {'name': 'students14', 'chinese': 81, 'english': 77, 'math': 61, 'history': 75, 'health': 71}
# {'name': 'students15', 'chinese': 79, 'english': 88, 'math': 58, 'history': 69, 'health': 56}
# {'name': 'students16', 'chinese': 72, 'english': 79, 'math': 59, 'history': 95, 'health': 92}
# {'name': 'students17', 'chinese': 100, 'english': 72, 'math': 70, 'history': 96, 'health': 52}
# {'name': 'students18', 'chinese': 98, 'english': 58, 'math': 95, 'history': 61, 'health': 92}
# {'name': 'students19', 'chinese': 70, 'english': 83, 'math': 98, 'history': 78, 'health': 57}
# {'name': 'students20', 'chinese': 97, 'english': 97, 'math': 90, 'history': 100, 'health': 79}
# {'name': 'students21', 'chinese': 56, 'english': 67, 'math': 80, 'history': 79, 'health': 59}
# {'name': 'students22', 'chinese': 82, 'english': 87, 'math': 86, 'history': 93, 'health': 71}
# {'name': 'students23', 'chinese': 60, 'english': 70, 'math': 69, 'history': 93, 'health': 65}
# {'name': 'students24', 'chinese': 64, 'english': 66, 'math': 75, 'history': 95, 'health': 94}
# {'name': 'students25', 'chinese': 93, 'english': 93, 'math': 100, 'history': 88, 'health': 75}
# {'name': 'students26', 'chinese': 55, 'english': 51, 'math': 76, 'history': 79, 'health': 73}
# {'name': 'students27', 'chinese': 85, 'english': 64, 'math': 51, 'history': 100, 'health': 91}
# {'name': 'students28', 'chinese': 68, 'english': 96, 'math': 53, 'history': 75, 'health': 88}
# {'name': 'students29', 'chinese': 91, 'english': 63, 'math': 55, 'history': 51, 'health': 57}
# {'name': 'students30', 'chinese': 99, 'english': 58, 'math': 84, 'history': 97, 'health': 57}
# {'name': 'students31', 'chinese': 99, 'english': 98, 'math': 82, 'history': 86, 'health': 87}
# {'name': 'students32', 'chinese': 73, 'english': 76, 'math': 65, 'history': 91, 'health': 95}
# {'name': 'students33', 'chinese': 99, 'english': 66, 'math': 59, 'history': 92, 'health': 80}
# {'name': 'students34', 'chinese': 98, 'english': 62, 'math': 50, 'history': 62, 'health': 82}
# {'name': 'students35', 'chinese': 65, 'english': 77, 'math': 94, 'history': 98, 'health': 74}
# {'name': 'students36', 'chinese': 65, 'english': 50, 'math': 70, 'history': 73, 'health': 50}
# {'name': 'students37', 'chinese': 65, 'english': 85, 'math': 72, 'history': 90, 'health': 91}
# {'name': 'students38', 'chinese': 51, 'english': 60, 'math': 100, 'history': 58, 'health': 90}
# {'name': 'students39', 'chinese': 89, 'english': 54, 'math': 88, 'history': 54, 'health': 87}
# {'name': 'students40', 'chinese': 67, 'english': 64, 'math': 67, 'history': 98, 'health': 61}
# {'name': 'students41', 'chinese': 97, 'english': 91, 'math': 79, 'history': 100, 'health': 80}
# {'name': 'students42', 'chinese': 76, 'english': 53, 'math': 67, 'history': 75, 'health': 100}
# {'name': 'students43', 'chinese': 95, 'english': 53, 'math': 87, 'history': 92, 'health': 92}
# {'name': 'students44', 'chinese': 53, 'english': 66, 'math': 69, 'history': 58, 'health': 65}
# {'name': 'students45', 'chinese': 91, 'english': 95, 'math': 85, 'history': 99, 'health': 57}
# {'name': 'students46', 'chinese': 71, 'english': 93, 'math': 80, 'history': 76, 'health': 99}
# {'name': 'students47', 'chinese': 85, 'english': 74, 'math': 67, 'history': 93, 'health': 73}
# {'name': 'students48', 'chinese': 53, 'english': 58, 'math': 78, 'history': 82, 'health': 78}
# {'name': 'students49', 'chinese': 60, 'english': 65, 'math': 84, 'history': 66, 'health': 97}
# {'name': 'students50', 'chinese': 88, 'english': 98, 'math': 74, 'history': 55, 'health': 95}

# %%
import random
students = []
for i in range(1,51):
    students.append(
        {
            'name':f'students{i}',
         'chinese':random.randint(50,100),
         'english':random.randint(50,100),
         'math':random.randint(50,100),
         'history':random.randint(50,100),
         'health':random.randint(50,100)
         }
         )

students_str = str(students)
students_str
# Out:
# "[{'name': 'students1', 'chinese': 52, 'english': 72, 'math': 99, 'history': 57, 'health': 67}, {'name': 'students2', 'chinese': 73, 'english': 63, 'math': 74, 'history': 57, 'health': 99}, {'name': 'students3', 'chinese': 70, 'english': 76, 'math': 57, 'history': 60, 'health': 59}, {'name': 'students4', 'chinese': 52, 'english': 92, 'math': 95, 'history': 92, 'health': 99}, {'name': 'students5', 'chinese': 90, 'english': 85, 'math': 89, 'history': 69, 'health': 73}, {'name': 'students6', 'chinese': 58, 'english': 67, 'math': 60, 'history': 69, 'health': 71}, {'name': 'students7', 'chinese': 77, 'english': 100, 'math': 53, 'history': 68, 'health': 91}, {'name': 'students8', 'chinese': 93, 'english': 89, 'math': 96, 'history': 90, 'health': 78}, {'name': 'students9', 'chinese': 61, 'english': 92, 'math': 62, 'history': 84, 'health': 60}, {'name': 'students10', 'chinese': 56, 'english': 88, 'math': 64, 'history': 75, 'health': 81}, {'name': 'students11', 'chinese': 99, 'english': 51, 'math': 96, 'history': 73, 'health': 56}, {'name': 'students12', 'chinese': 82, 'english': 74, 'math': 98, 'history': 85, 'health': 69}, {'name': 'students13', 'chinese': 54, 'english': 88, 'math': 73, 'history': 90, 'health': 55}, {'name': 'students14', 'chinese': 79, 'english': 93, 'math': 92, 'history': 68, 'health': 70}, {'name': 'students15', 'chinese': 55, 'english': 94, 'math': 61, 'history': 90, 'health': 81}, {'name': 'students16', 'chinese': 84, 'english': 58, 'math': 50, 'history': 68, 'health': 57}, {'name': 'students17', 'chinese': 69, 'english': 65, 'math': 59, 'history': 97, 'health': 98}, {'name': 'students18', 'chinese': 81, 'english': 74, 'math': 58, 'history': 100, 'health': 78}, {'name': 'students19', 'chinese': 52, 'english': 51, 'math': 88, 'history': 64, 'health': 91}, {'name': 'students20', 'chinese': 59, 'english': 86, 'math': 70, 'history': 73, 'health': 88}, {'name': 'students21', 'chinese': 61, 'english': 83, 'math': 58, 'history': 63, 'health': 67}, {'name': 'students22', 'chinese': 61, 'english': 71, 'math': 82, 'history': 57, 'health': 81}, {'name': 'students23', 'chinese': 100, 'english': 70, 'math': 96, 'history': 81, 'health': 97}, {'name': 'students24', 'chinese': 61, 'english': 53, 'math': 50, 'history': 62, 'health': 64}, {'name': 'students25', 'chinese': 78, 'english': 64, 'math': 70, 'history': 78, 'health': 50}, {'name': 'students26', 'chinese': 57, 'english': 95, 'math': 91, 'history': 66, 'health': 71}, {'name': 'students27', 'chinese': 72, 'english': 50, 'math': 82, 'history': 67, 'health': 98}, {'name': 'students28', 'chinese': 61, 'english': 87, 'math': 84, 'history': 92, 'health': 53}, {'name': 'students29', 'chinese': 93, 'english': 81, 'math': 86, 'history': 92, 'health': 52}, {'name': 'students30', 'chinese': 100, 'english': 73, 'math': 71, 'history': 88, 'health': 54}, {'name': 'students31', 'chinese': 69, 'english': 51, 'math': 60, 'history': 70, 'health': 76}, {'name': 'students32', 'chinese': 58, 'english': 88, 'math': 93, 'history': 97, 'health': 77}, {'name': 'students33', 'chinese': 94, 'english': 79, 'math': 51, 'history': 62, 'health': 61}, {'name': 'students34', 'chinese': 55, 'english': 80, 'math': 92, 'history': 57, 'health': 62}, {'name': 'students35', 'chinese': 86, 'english': 58, 'math': 55, 'history': 53, 'health': 61}, {'name': 'students36', 'chinese': 82, 'english': 80, 'math': 62, 'history': 72, 'health': 56}, {'name': 'students37', 'chinese': 63, 'english': 58, 'math': 62, 'history': 58, 'health': 60}, {'name': 'students38', 'chinese': 56, 'english': 85, 'math': 64, 'history': 62, 'health': 97}, {'name': 'students39', 'chinese': 84, 'english': 99, 'math': 71, 'history': 67, 'health': 57}, {'name': 'students40', 'chinese': 85, 'english': 84, 'math': 94, 'history': 74, 'health': 54}, {'name': 'students41', 'chinese': 58, 'english': 78, 'math': 73, 'history': 84, 'health': 86}, {'name': 'students42', 'chinese': 57, 'english': 72, 'math': 60, 'history': 92, 'health': 85}, {'name': 'stu ...

# %%
print(students_str,file=open('students.txt',mode='w',encoding='utf-8'))
