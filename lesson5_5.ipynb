# %%
import requests

url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    response = requests.get(url)
    response.raise_for_status()  # 檢查HTTP狀態碼，確保請求成功

    data = response.json()  # 將JSON格式的資料轉換為Python字典

    print('YouBike即時資訊下載完成！')

except requests.exceptions.RequestException as e:
    print(f'下載YouBike即時資訊時發生錯誤：{e}')
# Out:
# YouBike即時資訊下載完成！

# %%
import pandas as pd

df = pd.DataFrame(data)
df[['sna','ar','available_rent_bikes','available_return_bikes','total']]
# Out:
#                          sna             ar  available_rent_bikes  \
# 0         YouBike2.0_捷運科技大樓站    復興南路二段235號前                    17
# 1     YouBike2.0_復興南路二段273號前   復興南路二段273號西側                    11
# 2       YouBike2.0_國北教大實小東側門    和平東路二段96巷7號                    12
# 3          YouBike2.0_和平公園東側  和平東路二段118巷33號                     3
# 4       YouBike2.0_辛亥復興路口西北側     復興南路二段368號                     3
# ...                      ...            ...                   ...
# 1523      YouBike2.0_臺大禮賢樓西側      臺大禮賢樓西側空地                    11
# 1524    YouBike2.0_臺大大一女餐廳廣場    臺大大一女餐廳廣場後方                    10
# 1525        YouBike2.0_臺大學新館         臺大學新館旁                    11
# 1526     YouBike2.0_臺大水源舍區C棟     臺大水源舍區C棟西側                    36
# 1527        YouBike2.0_臺大人文館       臺大人文館東北側                    30
#
#       available_return_bikes  total
# 0                         11     28
# 1                         10     21
# 2                          4     16
# 3                          8     11
# 4                         13     16
# ...                      ...    ...
# 1523                      25     36
# 1524                      13     40
# 1525                      22     33
# 1526                      63     99
# 1527                      37     67
#
# [1528 rows x 5 columns]
